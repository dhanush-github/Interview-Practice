# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q1: ORDER OVER 200 DOLLARS

# %% [markdown]
# ## Problem Statement:
#
# - you are given two data frames. orders & items
#
# - orders dataframe contains orderids, item ids and quantity of each item ordered.
#
# - items data frame contains: item ids and prices.
#
#
# write a function to return a dataframe containing every order with a total value > $200
# Include total value of order as a value in the data frame

# %%
# in order to solve this problem, lets try to build the logical approach first and proceed to accordingly then.

"""

    1. read the data frames: load orders & items from csv files.
    2. merge the data frames: join two data frames on common column/feature (item_id).
    3. Calculate total value: add a new column to the merged data frame representing total value of each order.
    4. filter orders: filter the data frame to include only orders with value > $200.
    5. select columns: select and order columns  as specified.

"""
# Out:
# '\n\n    1. read the data frames: load orders & items from csv files.\n    2. merge the data frames: join two data frames on common column/feature (item_id).\n    3. Calculate total value: add a new column to the merged data frame representing total value of each order.\n    4. filter orders: filter the data frame to include only orders with value > $200.\n    5. select columns: select and order columns  as specified.\n\n'

# %%
orders = pd.read_excel("orders&itemsdata.csv.xlsx", sheet_name="orders")
items = pd.read_excel("orders&itemsdata.csv.xlsx", sheet_name="items")

# %%
orders
# Out:
#     order_id  item_id  quantity
# 0          1      205         3
# 1          2      217         6
# 2          3      219         3
# 3          4      217         1
# 4          5      220         5
# ..       ...      ...       ...
# 94        95      207         1
# 95        96      216         6
# 96        97      218         8
# 97        98      204         8
# 98        99      217         2
#
# [99 rows x 3 columns]

# %%
items
# Out:
#     item_id  price
# 0       205     50
# 1       217     38
# 2       219     77
# 3       217     72
# 4       220     67
# ..      ...    ...
# 94      207     92
# 95      216     27
# 96      218     83
# 97      204     78
# 98      217     21
#
# [99 rows x 2 columns]

# %%
# merging data frames

merged_df = pd.merge(orders, items, on="item_id")

# %%
merged_df
# Out:
#      order_id  item_id  quantity  price
# 0           1      205         3     50
# 1           1      205         3     60
# 2           1      205         3     83
# 3           1      205         3     35
# 4           1      205         3     35
# ..        ...      ...       ...    ...
# 542        99      217         2     55
# 543        99      217         2     61
# 544        99      217         2     76
# 545        99      217         2     52
# 546        99      217         2     21
#
# [547 rows x 4 columns]

# %%
# creating a new calculated column

merged_df["total_value"] = merged_df["quantity"] * merged_df["price"]

# %%
merged_df
# Out:
#      order_id  item_id  quantity  price  total_value
# 0           1      205         3     50          150
# 1           1      205         3     60          180
# 2           1      205         3     83          249
# 3           1      205         3     35          105
# 4           1      205         3     35          105
# ..        ...      ...       ...    ...          ...
# 542        99      217         2     55          110
# 543        99      217         2     61          122
# 544        99      217         2     76          152
# 545        99      217         2     52          104
# 546        99      217         2     21           42
#
# [547 rows x 5 columns]

# %%
filtered_df = merged_df[merged_df["total_value"] > 200]

filtered_df
# Out:
#      order_id  item_id  quantity  price  total_value
# 2           1      205         3     83          249
# 8           2      217         6     38          228
# 9           2      217         6     72          432
# 10          2      217         6     77          462
# 11          2      217         6     55          330
# ..        ...      ...       ...    ...          ...
# 534        98      204         8     64          512
# 535        98      204         8     44          352
# 536        98      204         8     86          688
# 537        98      204         8     96          768
# 538        98      204         8     78          624
#
# [341 rows x 5 columns]

# %% [markdown]
# ## Q2: CUSTOMER ANALYSIS

# %% [markdown]
# PROBLEM STATEMENT:
#
# - you are given a dataframe containing booking data from a hotel with columns: guest_Id, gender & date of booking
#
# - create a new dataset with summkary of information on their bookings including columns: guest_id, gender, most_recent_booking, booking_count.
#
# - most recent booking should diplay the date of guests most recent booking and booking count should display the count of bookings guest has made.

# %%
# lets try to build logical approach first.

"""

    1. load the data
    2. convert dates.
    3. group and aggregate.
    4. create the summary.
    5. return the result.

"""
# Out:
# '\n\n    1. load the data\n    2. convert dates.\n    3. group and aggregate.\n    4. create the summary.\n    5. return the result.\n\n'

# %%
bookings = pd.read_csv("BookingsData.csv")

# %%
bookings
# Out:
#     guest_id gender date_of_booking
# 0        101      M      12-02-2021
# 1        102      F      30-05-2022
# 2        103      F      24-07-2020
# 3        104      M      08-04-2022
# 4        105      F      23-05-2020
# 5        106      M      21-11-2020
# 6        107      F      14-06-2021
# 7        108      M      16-10-2021
# 8        109      F      05-06-2023
# 9        110      M      11-10-2022
# 10       111      F      07-11-2022
# 11       112      M      29-04-2021
# 12       113      F      07-10-2022
# 13       114      M      04-03-2021
# 14       110      M      12-03-2023
# 15       111      F      27-05-2020
# 16       112      M      26-02-2020
# 17       113      F      24-04-2021
# 18       114      M      23-12-2020
# 19       115      F      23-03-2024
# 20       105      F      06-12-2020
# 21       106      M      15-03-2021
# 22       107      F      30-08-2021
# 23       108      M      07-05-2021
# 24       109      F      25-07-2022
# ...

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   guest_id         49 non-null     int64
#  1   gender           49 non-null     object
#  2   date_of_booking  49 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
# converting date of booking column to date time format

bookings["date_of_booking"] = pd.to_datetime(bookings["date_of_booking"],dayfirst=True)

# %%
# group by guest id and gender to fetch most recent booking and count

summary_df = bookings.groupby(["guest_id","gender"]).agg(
    most_recent_booking = ("date_of_booking", "max"),
    booking_count = ("date_of_booking","count")

).reset_index()

# %%
summary_df
# Out:
#     guest_id gender most_recent_booking  booking_count
# 0        101      M          2021-02-12              1
# 1        102      F          2022-05-30              1
# 2        103      F          2020-07-24              1
# 3        104      M          2022-04-08              1
# 4        105      F          2020-12-06              2
# 5        106      M          2021-03-15              2
# 6        107      F          2021-08-30              2
# 7        108      M          2021-10-16              2
# 8        109      F          2023-06-05              2
# 9        110      M          2023-03-12              3
# 10       111      F          2023-03-20              3
# 11       112      M          2021-04-29              3
# 12       113      F          2022-10-07              3
# 13       114      M          2023-03-08              3
# 14       115      F          2024-03-23              2
# 15       116      M          2022-06-29              1
# ...

# %% [markdown]
# Q3: ENROLLMENTS IN UNIVERSITY

# %%
enrollments = pd.read_csv("enrollments.csv")

# %%
enrollments
# Out:
#     enrollment_id  student_id course_name   department enrollment_date
# 0               1         101    Calculus  Mathematics      15-05-2017
# 1               2         102    Calculus  Mathematics      23-07-2020
# 2               3         103    Calculus  Mathematics      13-03-2017
# 3               4         104    Calculus  Mathematics      12-06-2016
# 4               5         105    Calculus  Mathematics      26-01-2016
# 5               6         106    Calculus  Mathematics      22-04-2017
# 6               7         107    Calculus  Mathematics      19-08-2017
# 7               8         108    Calculus  Mathematics      17-11-2020
# 8               9         109    Calculus  Mathematics      24-07-2017
# 9              10         110    Calculus  Mathematics      07-05-2020
# 10             11         101     Physics      Science      31-05-2018
# 11             12         101     Algebra  Mathematics      01-08-2017
# ...

# %%
enrollments["enrollment_date"] = pd.to_datetime(enrollments["enrollment_date"])
enrollments = enrollments.sort_values(by="enrollment_date")

# %%
previous_enrollments = {}

def check_previous_enrollments(row):
    student_id = row["student_id"]
    department = row["department"]

    if student_id not in previous_enrollments:
        previous_enrollments[student_id] = set()
    if department in previous_enrollments[student_id]:
        return 1

    else:
        previous_enrollments[student_id].add(department)
        return 0


enrollments["department_previously_enrolled"] = enrollments.apply(check_previous_enrollments, axis=1)

# %%
enrollments_final = enrollments[["course_name", "department_previously_enrolled"]]

# %%
enrollments_final
# Out:
#    course_name  department_previously_enrolled
# 4     Calculus                               0
# 13     Algebra                               0
# 3     Calculus                               0
# 14   Chemistry                               0
# 20   Chemistry                               0
# 2     Calculus                               0
# 5     Calculus                               0
# 0     Calculus                               0
# 24     Algebra                               1
# 8     Calculus                               0
# 11     Algebra                               1
# 6     Calculus                               0
# 10     Physics                               0
# 25     Algebra                               1
# 22     Physics                               0
# 21     Physics                               0
# 12     Physics                               0
# 18   Chemistry                               1
# 19   Chemistry                               0
# ...

# %% [markdown]
# Q4: USERS BY AVERAGE TIME

# %%
user_activities = pd.read_csv("user_activities.csv")

# %%
user_activities
# Out:
#     user_id  action         timestamp
# 0         1   login  01-01-2023 08:00
# 1         1  logout  01-01-2023 09:00
# 2         2   login  02-01-2023 09:00
# 3         2  logout  02-01-2023 09:03
# 4         2   login  04-01-2023 08:50
# 5         2  logout  04-01-2023 09:00
# 6         3   login  06-01-2023 09:00
# 7         3  logout  06-01-2023 09:30
# 8         1   login  18-02-2023 19:30
# 9         1  logout  18-02-2023 19:35
# 10        1   login  19-02-2023 09:30
# 11        1  logout  19-02-2023 09:38
# 12        2   login  20-02-2023 06:38
# 13        2  logout  20-02-2023 09:48
# 14        2   login  22-02-2023 09:38
# 15        2  logout  22-02-2023 07:58
# 16        3   login  24-02-2023 08:33
# 17        3  logout  24-02-2023 08:40
# 18        4   login  26-02-2023 09:38
# 19        4  logout  26-02-2023 10:38
# 20        2   login  28-02-2023 09:38
# 21        2  logout  28-02-2023 11:15
# 22        2   login  02-03-2023 09:38
# 23        2  logout  02-03-2023 09:39
# ...

# %%
user_activities["timestamp"] = pd.to_datetime(user_activities["timestamp"], dayfirst=True)

login_df = user_activities[user_activities["action"] == "login"][["user_id","timestamp"]]

logout_df = user_activities[user_activities["action"] == "logout"][["user_id","timestamp"]]

# %%
df = pd.merge(login_df, logout_df, on='user_id', suffixes=['_login', '_logout'])

# Filter out invalid sessions where login happens after logout
df = df[df['timestamp_login'] < df['timestamp_logout']]

# Extract the date from the login timestamp
df['date'] = df['timestamp_login'].dt.floor('d')
# Out:
# <ipython-input-35-f1a7db28a56a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['timestamp_login'].dt.floor('d')

# %%
# Group by user_id and date, then get the max login and min logout for each group
df = df.groupby(['user_id', 'date']).agg(
    timestamp_login=('timestamp_login', 'max'),
    timestamp_logout=('timestamp_logout', 'min')
).reset_index()

# Calculate session duration in seconds
df['duration'] = (df['timestamp_logout'] - df['timestamp_login']).dt.total_seconds()

# %%
# Calculate the average session duration per user
result = df.groupby('user_id')['duration'].mean().reset_index()

# Rename the duration column
result.rename(columns={'duration': 'average_session_duration'}, inplace=True)

# Display the result
print(result)
# Out:
#    user_id  average_session_duration
# 0        1                    1460.0
# 1        2                   90380.0
# 2        3                    1110.0
# 3        4                    3570.0
# 4        5                   16920.0

# %% [markdown]
# Q5: MARKETING CAMPAIGN SUCCESS

# %%
visits = pd.read_csv("visits.csv")

# %%
visits.head()
# Out:
#    visit_id  user_id page_visited  visit_date
# 0         1      101     Homepage  23-02-2013
# 1         2      102     Homepage  27-03-2015
# 2         3      103      Contact  17-09-2014
# 3         4      104     Homepage  07-02-2018
# 4         5      105     Homepage  19-07-2021

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   visit_id      30 non-null     int64
#  1   user_id       30 non-null     int64
#  2   page_visited  30 non-null     object
#  3   visit_date    30 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.1+ KB

# %%
visits["visit_date"] = pd.to_datetime(visits["visit_date"])
# Out:
# <ipython-input-42-26de36966b2c>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   visits["visit_date"] = pd.to_datetime(visits["visit_date"])

# %%
# Get the first visit date for each user
first_visit_dates = visits.groupby('user_id')['visit_date'].min().reset_index()
first_visit_dates.rename(columns={'visit_date': 'first_visit_date'}, inplace=True)

# %%
# Merge the first visit dates with the original visits dataframe
visits = pd.merge(visits, first_visit_dates, on='user_id')

# Filter out visits that occur on the first visit date
df_subsequent_visits = visits[visits['visit_date'] > visits['first_visit_date']]

# Check for unique engagements (new pages visited after the first visit date)
unique_engagements = df_subsequent_visits.groupby('user_id')['page_visited'].nunique().reset_index()
unique_engagements.rename(columns={'page_visited': 'unique_pages_visited'}, inplace=True)

# Count the number of users who engaged with additional content
engaged_users_count = unique_engagements[unique_engagements['unique_pages_visited'] > 0].shape[0]

# %%
# Print the result
print(f"Number of users engaged with additional content: {engaged_users_count}")
# Out:
# Number of users engaged with additional content: 7
